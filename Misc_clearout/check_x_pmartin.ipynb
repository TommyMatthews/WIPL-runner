# %%
from WIPL_python_analysis.SinglePolPlots import SinglePolPlots
from WIPL_python_analysis.DualPol import DualPol
import sys

sys.path.append('./')

# %% [markdown]
# # Single pol

# %%
xh_plotter = SinglePolPlots('X_H_alternate_run_df.csv')
xv_plotter = SinglePolPlots('X_V_alternate_run_df.csv')

# %%
xh_plotter.plot_corrected_rcs(title='XH RCS purple martin')

# %%
xv_plotter.plot_corrected_rcs()

# %% [markdown]
# # Dual pol

# %%
x_dp = DualPol('X_H_alternate_run_df.csv', 'X_V_alternate_run_df.csv', hacky_fix=True)

# %%
x_dp.plot_differential_reflectivity(title = 'Differential reflectivity for purple martin model at X band')

# %%
x_dp.plot_differential_phase(title = 'Differential phase for purple martin model at X band')

# %%
x_dp.plot_differential_phase(title = 'Differential phase for purple martin model at X band', de_alias=True)
